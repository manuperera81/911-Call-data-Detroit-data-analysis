# %%
import pandas as pd
# to make numbers easier to read on display
pd.options.display.float_format='{:20.2f}'.format

#show all the columns on output
pd.set_option('display.max.columns',999)

# %% [markdown]
# ### Data Exploration

# %%
df_call_data_2020 = pd.read_csv('./data/Police_Serviced_911_Calls_2020.csv')

# %%
df_call_data_2020.head(10)
# Out:
#                      X                    Y   incident_id  \
# 0               -83.03                42.34  202036604512
# 1               -83.01                42.39  202036604511
# 2               -83.22                42.36  202036604491
# 3               -83.29                42.43  202036604482
# 4               -82.91                42.42  202036604481
# 5               -83.07                42.43  202036604476
# 6               -83.26                42.38  202036604467
# 7               -82.95                42.43  202036604463
# 8               -83.12                42.39  202036604457
# 9               -83.10                42.37  202036604453
#
#               incident_location call_source                call_description  \
# 0  Chestnut St & Saint Aubin St       W911                   SHOTS FIRED IP
# 1      Harper Ave & Raymond Ave       W911   VERIFIED ALR / PERSON W/O CODE
# 2   Ashton Ave & Fitzpatrick St       W911       BURGLARY OCCUPIED RESD I/P
# ...

# %%
df_call_data_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274769 entries, 0 to 274768
# Data columns (total 25 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   X                    274324 non-null  float64
#  1   Y                    274324 non-null  float64
#  2   incident_id          274769 non-null  int64
#  3   incident_location    274427 non-null  object
#  4   call_source          274769 non-null  object
#  5   call_description     274769 non-null  object
#  6   category             274769 non-null  object
#  7   priority             274769 non-null  object
#  8   call_group           274769 non-null  object
#  9   call_code            274769 non-null  object
#  10  called_at            274769 non-null  object
#  11  intake_time          274769 non-null  float64
#  12  dispatch_time        274522 non-null  float64
#  13  travel_time          274769 non-null  float64
# ...

# %%
df_call_data_2020.describe()
# Out:
#                          X                    Y          incident_id  \
# count            274324.00            274324.00            274769.00
# mean                -83.11                42.39      202018579004.69
# std                   0.10                 0.04          10134301.07
# min                 -83.29                42.23      202000100009.00
# 25%                 -83.19                42.36      202010203817.00
# 50%                 -83.12                42.39      202018702977.00
# 75%                 -83.03                42.42      202027000534.00
# max                 -82.89                42.47      202036604512.00
#
#                intake_time        dispatch_time          travel_time  \
# count            274769.00            274522.00            274769.00
# mean                  1.60                20.30                 7.57
# std                   8.93                44.17               336.06
# ...

# %%
#check missing values
df_call_data_2020.isnull().sum()
# Out:
# X                       445
# Y                       445
# incident_id               0
# incident_location       342
# call_source               0
# call_description          0
# category                  0
# priority                  0
# call_group                0
# call_code                 0
# called_at                 0
# intake_time               0
# dispatch_time           247
# travel_time               0
# on_scene_time             6
# total_response_time       0
# total_time                6
# zip_code                  0
# precinct                547
# scout_car_area            0
# neighborhood_name      5140
# council_district       4661
# longitude               342
# latitude                342
# ESRI_OID                  0
# dtype: int64

# %%
#handle missing null values
